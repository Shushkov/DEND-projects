# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays where song_id is not null  limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(5662, 1542837407796, 15, 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(73, 'Jacob', 'Klein', 'M', 'paid'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (54, 'Kaleb', 'Cook', 'M', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 25;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 25 rows affected.
# [('SOFNOQK12AB01840FC', 'ARNNKDK1187B98BBD5', 'Kutt Free (DJ Volume Remix)', Decimal('407.38'), 0),
#  ('SOBAYLL12A8C138AF9', 'ARDR4AC1187FB371A1', 'Sono andati? Fingevo di dormire', Decimal('511.16'), 0),
#  ('SOFFKZS12AB017F194', 'ARBEBBY1187B9B43DB', 'A Higher Place (Album Version)', Decimal('236.17'), 1994),
#  ('SOGVQGJ12AB017F169', 'AR62SOJ1187FB47BB5', 'Ten Tonne', Decimal('337.68'), 2005),
#  ('SOXILUQ12A58A7C72A', 'ARP6N5A1187B99D1A3', 'Jenny Take a Ride', Decimal('207.44'), 2004),
#  ('SOLEYHO12AB0188A85', 'ARAGB2O1187FB3A161', 'Got My Mojo Workin', Decimal('338.23'), 0),
#  ('SOBKWDJ12A8C13B2F3', 'AR36F9J1187FB406F1', 'Wild Rose (Back 2 Basics Mix)', Decimal('230.71'), 0),
#  ('SOOJPRH12A8C141995', 'ARBGXIG122988F409D', 'Loaded Like A Gun', Decimal('173.19'), 0),
#  ('SOPEGZN12AB0181B3D', 'AREDL271187FB40F44', 'Get Your Head Stuck On Your Neck', Decimal('45.66'), 0),
# ...

# %%
# %sql SELECT * FROM artists LIMIT 100;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 69 rows affected.
# [('ARNNKDK1187B98BBD5', Decimal('45.807259999999999'), Decimal('15.967599999999999'), 'Zagreb Croatia', 'Jinx'),
#  ('ARDR4AC1187FB371A1', Decimal('NaN'), Decimal('NaN'), '', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti'),
#  ('ARBEBBY1187B9B43DB', Decimal('NaN'), Decimal('NaN'), 'Gainesville, FL', 'Tom Petty'),
#  ('AR62SOJ1187FB47BB5', Decimal('NaN'), Decimal('NaN'), '', 'Chase & Status'),
#  ('ARP6N5A1187B99D1A3', Decimal('NaN'), Decimal('NaN'), 'Hamtramck, MI', 'Mitch Ryder'),
#  ('ARAGB2O1187FB3A161', Decimal('NaN'), Decimal('NaN'), '', 'Pucho & His Latin Soul Brothers'),
#  ('AR36F9J1187FB406F1', Decimal('56.276090000000003'), Decimal('9.5169499999999996'), 'Denmark', 'Bombay Rockers'),
#  ('ARBGXIG122988F409D', Decimal('37.779159999999997'), Decimal('-122.42005'), 'California - SF', 'Steel Rain'),
# ...

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1543449657796, 0, 29, 48, 11, 2018, 3),
#  (1543449690796, 0, 29, 48, 11, 2018, 3),
#  (1543449841796, 0, 29, 48, 11, 2018, 3),
#  (1543449895796, 0, 29, 48, 11, 2018, 3),
#  (1543450033796, 0, 29, 48, 11, 2018, 3)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql select sng.* from songs sng join artists art on sng.artist_id=art.id where sng.title ='Setanta matins' and art.name ='Elena' and duration=269.58;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', 'Setanta matins', Decimal('269.58'), 0)]

# %%
# %sql SELECT sng.*,ss.title, art.name FROM songplays sng join songs ss on sng.song_id = ss.id join artists art on art.id = sng.artist_id  limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(5662, 1542837407796, 15, 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"', 'Setanta matins', 'Elena')]

# %%
# %sql select count(user_agent) as amount, user_agent from songplays group by user_agent order by amount desc;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 40 rows affected.
# [(971, '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (708, '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (696, 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (577, '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (573, '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
#  (443, 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (427, '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
# ...

# %%
# %sql select tt.*, users.first_name, title from songplays join users on user_id=users.id join time tt on tt.start_time = songplays.start_time join songs ss on songplays.song_id = ss.id order by first_name, start_time Limit 100;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(1542837407796, 21, 21, 47, 11, 2018, 2, 'Lily', 'Setanta matins')]
